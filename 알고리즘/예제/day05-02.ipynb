# %%
katok = []
select = -1	
print(katok)
# Out:
# []

# %%
katok = []
print(len(katok))
katok.append(None)
print(katok)
print(len(katok))
print(katok[0])
katok[0] = '철수'
print(katok[0])
print(katok)
# Out:
# 0
# [None]
# 1
# None
# 철수
# ['철수']

# %%
katok.append(None)
print(katok)
katok.append(None)
print(katok)
# Out:
# ['철수', None]
# ['철수', None, None]

# %%
katok[1] = '영희'
print(katok)
# Out:
# ['철수', '영희', None]

# %%
katok[2] = '민수'
print(katok)
# Out:
# ['철수', '영희', '민수']

# %%
katok.append(None)
print(katok)
# Out:
# ['철수', '영희', '민수', None]

# %%
katok[3] = katok[2]
katok[2] = None
print(katok)
# Out:
# ['철수', '영희', None, '민수']

# %%
katok[2] = katok[1]
katok[1] = None
print(katok)
# Out:
# ['철수', None, '영희', '민수']

# %%
katok[1] = '영수'
print(katok)
# Out:
# ['철수', '영수', '영희', '민수']

# %%
katok[2] = None
print(katok)
# Out:
# ['철수', '영수', None, '민수']

# %%
katok[2] = katok[3]
print(katok)
# Out:
# ['철수', '영수', '민수', '민수']

# %%
del(katok[3])
print(katok)
# Out:
# ['철수', '영수', '민수']
